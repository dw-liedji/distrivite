# %%
import os
import django

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "quanta.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %%
from apps.users.models import User

import csv
import os

# %%
import time
from django.db import transaction

# %%
# utils/data_migration.py (continued)
from decimal import Decimal
from django.utils import timezone
from phonenumber_field.phonenumber import PhoneNumber
from apps.orders.models import (
    Customer, Category, Item, Supplier, Batch, Stock,
    Facturation, FacturationStock, Transaction,
    FacturationPayment, Organization, OrganizationUser as NewOrganizationUser
)

# %%
from django.contrib.auth.models import Permission

# %%
permissions = Permission.objects.all()

# %%
for permission in permissions:
    print(f"{permission.content_type.app_label}.{permission.codename}")
# Out:
# account.add_emailaddress
# account.change_emailaddress
# account.delete_emailaddress
# account.view_emailaddress
# account.add_emailconfirmation
# account.change_emailconfirmation
# account.delete_emailconfirmation
# account.view_emailconfirmation
# admin.add_logentry
# admin.change_logentry
# admin.delete_logentry
# admin.view_logentry
# auth.add_group
# auth.change_group
# auth.delete_group
# auth.view_group
# auth.add_permission
# auth.change_permission
# auth.delete_permission
# auth.view_permission
# contenttypes.add_contenttype
# contenttypes.change_contenttype
# contenttypes.delete_contenttype
# contenttypes.view_contenttype
# core.add_faq
# core.change_faq
# core.delete_faq
# core.view_faq
# orders.add_batch
# orders.change_batch
# orders.delete_batch
# orders.view_batch
# orders.add_bulkcreditpayment
# orders.change_bulkcreditpayment
# orders.delete_bulkcreditpayment
# orders.view_bulkcreditpayment
# orders.add_category
# orders.change_category
# orders.delete_category
# orders.view_category
# orders.add_customer
# orders.change_customer
# orders.delete_customer
# orders.view_customer
# orders.add_facturation
# orders.change_facturation
# orders.delete_facturation
# orders.deliver_facturation
# orders.print_facturation
# orders.view_facturation
# orders.add_facturationpayment
# orders.change_facturationpayment
# orders.delete_facturationpayment
# orders.view_facturationpayment
# orders.add_facturationrefund
# orders.change_facturationrefund
# orders.delete_facturationrefund
# orders.view_facturationrefund
# orders.add_facturationstock
# orders.change_facturationstock
# orders.delete_facturationstock
# orders.deliver_facturationstock
# orders.view_facturationstock
# orders.add_item
# orders.change_item
# orders.delete_item
# orders.view_item
# orders.add_stock
# orders.change_stock
# orders.change_stockprice
# orders.delete_stock
# orders.view_stock
# orders.add_supplier
# orders.change_supplier
# orders.delete_supplier
# orders.view_supplier
# orders.add_transaction
# orders.change_transaction
# orders.delete_transaction
# orders.print_transaction
# orders.view_transaction
# organization.add_organization
# organization.change_organization
# organization.delete_organization
# organization.view_organization
# organization.view_organizationdashboard
# organization.add_organizationgroup
# organization.change_organizationgroup
# organization.delete_organizationgroup
# organization.view_organizationgroup
# organization.add_organizationinvitation
# organization.change_organizationinvitation
# organization.delete_organizationinvitation
# organization.view_organizationinvitation
# organization.add_organizationowner
# organization.change_organizationowner
# organization.delete_organizationowner
# organization.view_organizationowner
# organization.add_organizationuser
# organization.change_organizationuser
# organization.delete_organizationuser
# organization.view_organizationuser
# organization.add_organizationusergroup
# organization.change_organizationusergroup
# organization.delete_organizationusergroup
# organization.view_organizationusergroup
# organizations.add_organization
# organizations.change_organization
# organizations.delete_organization
# organizations.view_organization
# organizations.add_organizationinvitation
# organizations.change_organizationinvitation
# organizations.delete_organizationinvitation
# organizations.view_organizationinvitation
# organizations.add_organizationowner
# organizations.change_organizationowner
# organizations.delete_organizationowner
# organizations.view_organizationowner
# organizations.add_organizationuser
# organizations.change_organizationuser
# organizations.delete_organizationuser
# organizations.view_organizationuser
# sessions.add_session
# sessions.change_session
# sessions.delete_session
# sessions.view_session
# socialaccount.add_socialaccount
# socialaccount.change_socialaccount
# socialaccount.delete_socialaccount
# socialaccount.view_socialaccount
# socialaccount.add_socialapp
# socialaccount.change_socialapp
# socialaccount.delete_socialapp
# socialaccount.view_socialapp
# socialaccount.add_socialtoken
# socialaccount.change_socialtoken
# socialaccount.delete_socialtoken
# socialaccount.view_socialtoken
# subscriptions.add_feature
# subscriptions.change_feature
# subscriptions.delete_feature
# subscriptions.view_feature
# subscriptions.add_plan
# subscriptions.change_plan
# subscriptions.delete_plan
# subscriptions.view_plan
# subscriptions.add_planfeature
# subscriptions.change_planfeature
# subscriptions.delete_planfeature
# subscriptions.view_planfeature
# subscriptions.add_subscription
# subscriptions.change_subscription
# subscriptions.delete_subscription
# subscriptions.view_subscription
# users.add_user
# users.change_user
# users.delete_user
# users.view_user
