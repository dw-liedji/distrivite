# %%
import os
import django

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'rest.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %%
from django.contrib.contenttypes.models import ContentType

# %%
cts = ContentType.objects.filter(model__contains="productinfacturationdetails")
cts
# Out:
# <QuerySet [<ContentType: productinfacturationdetails>]>

# %%
cts.delete()
# Out:
# (5, {'auth.Permission': 4, 'contenttypes.ContentType': 1})

# %%
cts = ContentType.objects.filter(app_label__contains="bnpl", model__contains="")
cts
# Out:
# <QuerySet [<ContentType: bnplfacturation>, <ContentType: collector>, <ContentType: collectoraccount>, <ContentType: payment>, <ContentType: paymentplan>, <ContentType: productinbnplfacturation>]>

# %%
cts.delete()
# Out:
# (30, {'auth.Permission': 24, 'contenttypes.ContentType': 6})
