# %%
import os
import django

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'rest.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %%
from django.contrib.contenttypes.models import ContentType

# %%
content_types = ContentType.objects.all()

# %%
from django.apps import apps

# %%
for app in apps.get_app_configs():


    for model_name in app.models:
        model_custom_permissions = []
        model_custom_permissions_ids = []

        model = app.models[model_name]
        ct_id = ContentType.objects.get_for_model(
                    model, for_concrete_model=False
                ).pk
        print(model_name, model, ct_id)
        for content_type in content_types:
            if content_type.model == model_name and content_type.app_label == app.label:
                print(content_type.model,content_type.app_label, content_type.id, )
# Out:
# permission <class 'django.contrib.auth.models.Permission'> 1
# permission auth 1
# group_permissions <class 'django.contrib.auth.models.Group_permissions'> 62
# group_permissions auth 62
# group <class 'django.contrib.auth.models.Group'> 2
# group auth 2
# user <class 'django.contrib.auth.models.User'> 63
# user auth 63
# contenttype <class 'django.contrib.contenttypes.models.ContentType'> 3
# contenttype contenttypes 3
# session <class 'django.contrib.sessions.models.Session'> 4
# session sessions 4
# organization <class 'organizations.models.Organization'> 5
# organization organizations 5
# organizationuser <class 'organizations.models.OrganizationUser'> 7
# organizationuser organizations 7
# organizationowner <class 'organizations.models.OrganizationOwner'> 6
# organizationowner organizations 6
# organizationinvitation <class 'organizations.models.OrganizationInvitation'> 8
# organizationinvitation organizations 8
# user_groups <class 'apps.users.models.User_groups'> 64
# ...

# %%
# Out:
# permission auth 1
# group auth 2
# contenttype contenttypes 3
# session sessions 4
# organization organizations 5
# organizationowner organizations 6
# organizationuser organizations 7
# organizationinvitation organizations 8
# user users 9
# userprofile users 10
# organization organization 11
# organizationgroup organization 12
# organizationinvitation organization 13
# organizationowner organization 14
# organizationuser organization 15
# organizationusergroup organization 16
# attribute inventories 17
# catalog inventories 18
# catalogcategory inventories 19
# category inventories 20
# media inventories 21
# product inventories 22
# commercial orders 23
# Customer orders 24
# orderstatuscode orders 25
# productinpurchase orders 26
# productinfacturation orders 27
# purchase orders 28
# facturation orders 29
# supplier orders 30
# bnplfacturation bnpl 31
# collector bnpl 32
# collectoraccount bnpl 33
# payment bnpl 34
# paymentplan bnpl 35
# productinbnplfacturation bnpl 36
# ...
