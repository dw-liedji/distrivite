# %%
import os
import django

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'rest.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %%
from apps.users.models import User

# %%
user = User.objects.first()

# %%
user.organizations_organization.all()
# Out:
# <QuerySet []>

# %%
from apps.organization.models import Organization, OrganizationUser

# %%
organization = Organization.objects.filter(slug="creditium").first()

# %%
organization_user = organization.organization_users.all().first()
print(organization_user)
# Out:
#  (creditium3)

# %%
organization_user.user.email, organization_user.is_active, organization_user.is_admin, organization_user.is_owner
# Out:
# ('admin@admin.com', False, True, True)

# %%
organization.owner
# Out:
# <OrganizationOwner: creditium3:  (creditium3)>

# %%
user.organization_organization.all()
# Out:
# <QuerySet [<Organization: Hetelo>, <Organization: Quanta>, <Organization: creditium3>]>

# %%
organization.users.all().first()
# Out:
# <User: admin@admin.com>
