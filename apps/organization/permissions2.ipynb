# %%
import os
import django

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'dev.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %%
from apps.organization.models import OrganizationUser

# %%
org_user = OrganizationUser.objects.first()

# %%
org_user.has_perm(["digitalwater.view_consumption"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 org_user.has_perms(["digitalwater.view_consumption"])
#
# File ~/Datavite/products/datavite/apps/organization/models.py:232, in PermissionMixins.has_perms(self, perm_list, obj)
#     230 if not is_iterable(perm_list) or isinstance(perm_list, str):
#     231     raise ValueError("perm_list must be an iterable of permissions.")
# --> 232 return all(self.has_perm(perm, obj) for perm in perm_list)
#
# File ~/Datavite/products/datavite/apps/organization/models.py:232, in <genexpr>(.0)
#     230 if not is_iterable(perm_list) or isinstance(perm_list, str):
#     231     raise ValueError("perm_list must be an iterable of permissions.")
# --> 232 return all(self.has_perm(perm, obj) for perm in perm_list)
#
# File ~/Datavite/products/datavite/apps/organization/models.py:218, in PermissionMixins.has_perm(self, perms, obj)
#     209 """
#     210 Return True if the user has the specified permission. Query all
#     211 available auth backends, but return immediately if any backend returns
#    (...)
#     214 permissions for that object.
#     215 """
#     217 if not is_iterable(perms) or isinstance(perms, str):
# --> 218     raise ValueError("perm must be an iterable of permissions.")
#     220 # Active superusers have all permissions.
#     221 if self.is_active and self.is_superuser:
#
# ValueError: perm must be an iterable of permissions.

# %%
print(org_user)
# Out:
# LIEDJI Dagobert | ds

# %%
organization_user.user.email
# Out:
# 'admin@admin.com'

# %%
organization_user_perms = PermWrapper(organization_user),

# %%
list(organization_user.get_all_permissions())
# Out:
# ['inventories.change_inventory',
#  'inventories.delete_inventory',
#  'inventories.view_inventory',
#  'inventories.add_inventory']

# %%
if 'inventories.change_inventory' in organization_user.get_all_permissions():
    print("can change inventories")
# Out:
# can change inventories

# %%
organization_user.is_owner
# Out:
# True
