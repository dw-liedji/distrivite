# %%
import os
import django

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'quanta.settings.dev')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %%
from apps.organization.models import Organization, OrganizationUser

# %%
from apps.cashflow.models import CashRegister, Transaction, Deposit, Withdrawal

# %%
organization = Organization.objects.first()

# %%
organization.name

# %%
organization_user = OrganizationUser.objects.first()

# %%
cash_register = CashRegister.objects.create(name="Caisse principale", organization=organization)

# %%
cash_register.name

# %%
cash_register.transactions.all()

# %%
organization.cash_registers.all()

# %%
organization.deposits.all()

# %%
organization.withdrawals.all()

# %%
deposit1 = Deposit.objects.create(amount=500, cash_register=cash_register, organization_user=organization_user, organization=organization, reason="Achat de marchandise")

# %%
deposit1.amount

# %%
deposit1.reason

# %%
widthdrawal1 = Withdrawal.objects.create(amount=500, cash_register=cash_register, organization_user=organization_user, organization=organization, reason="Achat de nouriture pour manger")

# %%
widthdrawal1.amount

# %%
widthdrawal1.reason

# %%
print(deposit1)

# %%
print(widthdrawal1)

# %%
Transaction.objects.all()

# %%
for transaction in Transaction.objects.all():
    print(transaction,transaction.organization_user)

# %%
transaction

# %%
Transaction.objects.last()
