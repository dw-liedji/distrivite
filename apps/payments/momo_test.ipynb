# %% [markdown]
# ### MTN Mobile money credentials:
# Password : Python2&3.py.js.dwl

# %%
import os
import django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'rest.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %%
import uuid
print(uuid.uuid4())
# Out:
# 41cc158f-356d-4187-aa69-5ff6a3bdcc4b

# %%
import dotenv
dotenv.read_dotenv('../.env')

# %%
import dotenv
dotenv.read_dotenv('../.env')

config = {
   "ENVIRONMENT": os.environ.get("ENVIRONMENT"), 
   "BASE_URL": os.environ.get("BASE_URL"), 
   "CALLBACK_HOST": os.environ.get("CALLBACK_HOST"), # Mandatory.
   
   "COLLECTION_PRIMARY_KEY": os.environ.get("COLLECTION_PRIMARY_KEY"), 
   "COLLECTION_USER_ID": os.environ.get("COLLECTION_USER_ID"),
   "COLLECTION_API_SECRET": os.environ.get("COLLECTION_API_SECRET"),
#    "REMITTANCE_USER_ID": os.environ.get("REMITTANCE_USER_ID"), 
#    "REMITTANCE_API_SECRET": os.environ.get("REMITTANCE_API_SECRET"),
#    "REMITTANCE_PRIMARY_KEY": os.environ.get("REMITTANCE_PRIMARY_KEY"),
#    "DISBURSEMENT_USER_ID": os.environ.get("DISBURSEMENT_USER_ID"), 
#    "DISBURSEMENT_API_SECRET": os.environ.get("DISBURSEMENTS_API_SECRET"),
#    "DISBURSEMENT_PRIMARY_KEY": os.environ.get("DISBURSEMENT_PRIMARY_KEY"), 
}

# %%
print(config)
# Out:
# {'ENVIRONMENT': 'sandbox', 'BASE_URL': '127.0.0.1:8000', 'CALLBACK_HOST': 'https://webhook.site/b78a2001-c005-4995-9625-0f1bf4be1b54', 'COLLECTION_PRIMARY_KEY': '6a4d5c0d88ef46ae831aa8eca95cfec1', 'COLLECTION_USER_ID': '7b41b46d-7d4d-452b-ae8f-928a2c3aef2f', 'COLLECTION_API_SECRET': 'f4149833876749c0bf5add7e23423e11'}

# %%
import os
from mtnmomo.collection import Collection

# %%
from mtnmomo.collection import Collection
client = Collection({
        "COLLECTION_USER_ID": os.environ.get("COLLECTION_USER_ID"),
        "COLLECTION_API_SECRET": os.environ.get("COLLECTION_API_SECRET"),
        "COLLECTION_PRIMARY_KEY": os.environ.get("COLLECTION_PRIMARY_KEY"),
    })

# %%
import phonenumbers
from phonenumbers import carrier

# %%
number =phonenumbers.parse("+237672120240", None)

# %%
carrier.name_for_number(numobj=number, lang='en')
# Out:
# 'MTN Cameroon'

# %%
number.country_code
# Out:
# 237

# %%
client.requestToPay(
    mobile="+237672120240", 
    amount="200", 
    external_id="123456789", 
    payee_note="dd", 
    payer_message="dd", 
    currency="EUR"
    )
# Out:
# /home/liedji/.local/share/virtualenvs/afrisaas-F1V9sAHR/lib/python3.8/site-packages/urllib3/connectionpool.py:842: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn((
# <Response [202]>
# {'transaction_ref': '10709896-fe80-45a8-9f0d-cd1e5ba54b0b'}
