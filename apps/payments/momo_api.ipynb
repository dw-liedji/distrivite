# %% [markdown]
# ### # Password for mtn momo:Python2&3.py.js.dwl

# %% [markdown]
# It assumes you have created an account on https://momodeveloper.mtn.com and have your Ocp-Apim-Subscription-Key (_This is the primary key for the specific product subscription_).

# %% [markdown]
# We can use ```https://webhook.site/``` website for testing purpose but, for production, we should use our django back domain name

# %% [markdown]
# ```Bash
# $ providerCallBackHost: https://webhook.site/b78a2001-c005-4995-9625-0f1bf4be1b54
# $ Ocp-Apim-Subscription-Key: 6a4d5c0d88ef46ae831aa8eca95cfec1
# ```

# %% [markdown]
# #### We are going to get request similar the following message in the console:
# Here is your User Id and API secret :
#
# ```Js
# Here is your User Id and API secret : {'UserId': '607fcfe5-5f7b-451a-aa2f-824965e9eeae', 'APISecret': '87c5769203dd431d87b7d88089893abd'}
# ```
