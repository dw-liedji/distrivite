# %%
import os
import django

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'rest.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %%
from apps.subscriptions import models
from apps.organization.models import Organization

# %%
plans = models.Plan.objects.all()

# %%
first_plan = plans[0]

# %%
plan_features = first_plan.plan_features.all()

# %%
for plan_feature in plan_features:
    print(plan_feature.feature.name, plan_feature.feature.code, plan_feature.is_powerful)
# Out:
# 1 users 6 False
# card 2 False

# %%
organization = Organization.objects.first()

# %%
subscription = models.Subscription.objects.filter(organization=organization).last()

# %%
print(subscription.plan, subscription.is_active)
# Out:
# Starter False

# %%
features = models.Feature.objects.all()

# %%
for feature in features:
    print(feature.name, feature.code)
# Out:
# dashboard 1
# card 2
# ai assisstant 3
# finance 4
# 4 users 5
# 1 users 6

# %%
subscription.plan.plan_features.all()
# Out:
# <QuerySet [<PlanFeature: Starter | 1 users>, <PlanFeature: Starter | card>]>
