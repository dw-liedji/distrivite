# %%
import os
import django

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'focalflow.settings.dev')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %%
from apps.users.models import User, UserProfile
from apps.organization.models import Organization
from apps.cameis import models

# %%
from itertools import zip_longest

# %%
students = [i for i in range(1)]

# %%
iterators = [iter(students)]*2

# %%
print(iterators)
# Out:
# [<list_iterator object at 0x7fce017ac190>, <list_iterator object at 0x7fce017ac190>]

# %%
# data = list(zip_longest(*iterators))

# %%
for data1, data2 in zip_longest(*iterators):
    print(data1, data2)
# Out:
# 0 None
