# %%
import os
import django

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'quanta.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %%
from bokeh.io import output_notebook, show
output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Image as marker with bokeh
#
# ```Py
#
# p = figure(x_range=(0,500), y_range=(0,500))
# p.image_url(url=[ "http://pngimg.com/uploads/palm_tree/palm_tree_PNG2504.png",
#                   "https://www.referenseo.com/wp-content/uploads/2019/03/image-attractive.jpg"],
#              x=[1, 5], y=[1, 5], w=253, h=409, anchor="bottom_left", alpha=0.3)

# %%
from apps.inventories.models import Stock

# %%
df = Stock.objects.to_dataframe(index="id", fieldnames=["product_item__product__name", "location", "units", "units_sold", "product_item__attribute_values__attribute", "product_item__attribute_values__value", "expiration_date"])

# %%
df
# Out:
#    product_item__product__name location  units  units_sold  \
# id
# 1         Chemise camerounaise  Store 1      0          30
# 2         Chemise camerounaise  Store 2     50          56
# 3         Chemise camerounaise  Store 1   1000          30
# 4        Lean django by liedji  Dschang      9           6
#
#    product_item__attribute_values__attribute  \
# id
# 1                            Fashion | color
# 2                            Fashion | color
# 3                            Fashion | color
# 4                          document | editor
#
#    product_item__attribute_values__value           expiration_date
# id
# 1                                    red 2023-10-10 00:00:00+00:00
# 2                                   blue 2023-10-10 00:00:00+00:00
# 3                                    red 2022-10-10 00:00:00+00:00
# 4                                    red 2023-10-10 00:00:00+00:00

# %%
from bokeh.models import ColumnDataSource
cds = ColumnDataSource(data=df)

# %%
from bokeh.plotting import figure, show
p = figure(title="Stock data") 
p.line(x="id", y="units_sold", source=cds)
# Out:
# GlyphRenderer(id='p1058', ...)

# %%
show(p)
# Out:
#   <div id="a4fa6e3e-7879-4b73-ad99-4abf89c219fe" data-root-id="p1005" style="display: contents;"></div>

# %%
from bokeh.embed import components
script, div = components(p)

# %%
stock_history = Stock.history.all().order_by('-history_date')

# %%
for history_item in stock_history:
    print(history_item.history_date.strftime('%Y-%m-%d'), 
          history_item.history_type, 
          history_item.units, 
          history_item.history_change_reason, 
          history_item.product_item.product.name, 
          history_item.location, 
          history_item.organization, 
          history_item.history_user.username)
# Out:
# 2022-12-27 ~ 1000 None Chemise camerounaise Store 1 creditium admin
# 2022-12-27 + 9 None Lean django by liedji Dschang Hetelo admin
# 2022-12-26 + 0 None Chemise camerounaise Store 1 creditium admin
# 2022-12-26 + 50 None Chemise camerounaise Store 2 creditium admin
# 2022-12-26 + 0 Add a question Chemise camerounaise Store 1 creditium admin

# %%
stock_history.filter(
    history_user__username="admin", 
                     history_type="+" ).order_by("-history_date").count()
# Out:
# 4

# %%
stock = Stock.objects.first()

# %%
from simple_history.utils import update_change_reason

# %%
update_change_reason(stock, 'Add a question')

# %%
stock.history.last().history_change_reason
# Out:
# 'Add a question'

# %%
from apps.organization.models import Organization
stock.history.filter(organization=Organization.objects.first())
# Out:
# <HistoricalQuerySet []>

# %%
Stock.history_for_organization(organization="creditium")
# Out:
# <HistoricalQuerySet [<HistoricalStock: Stock object (3) as of 2022-12-27 17:01:29.968771+00:00>, <HistoricalStock: Stock object (3) as of 2022-12-26 19:16:49.562187+00:00>, <HistoricalStock: Stock object (2) as of 2022-12-26 19:13:42.819570+00:00>, <HistoricalStock: Stock object (1) as of 2022-12-26 19:11:43.329921+00:00>]>

# %%
stocks = Stock.objects.for_organization("creditium")

# %%
from django.db.models.aggregates import Sum

# %%
stocks_units_by_location = stocks.aaggregate(Sum('units'))

# %%
stocks_units_by_location
# Out:
# <coroutine object QuerySet.aaggregate at 0x7fb1245f0940>

# %%
from apps.inventories.models import Location

# %%
locations = Location.objects.for_organization(organization="creditium")

# %%
Stock.objects.for_organization(organization="creditium").filter(location__in=locations).count()
# Out:
# 3

# %%
for location in locations:
    print(location.stocks.aggregate(units=Sum("units")))
# Out:
# {'units': 1000}
# {'units': 50}

# %%
locations = Location.objects.for_organization(organization="creditium").annotate(units=Sum("stocks__units")).order_by("units")

# %%
for location in locations:
    print(location.units)
# Out:
# 50
# 1000

# %%
df = locations.to_dataframe(index="name", fieldnames=["name","units"])
cds = ColumnDataSource(df)

# %%
df
# Out:
#          units
# name
# Store 2     50
# Store 1   1000

# %%
from bokeh.plotting import figure, show

# %%
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure, show
from bokeh.palettes import Bright6
from bokeh.transform import factor_cmap
p = figure(x_range=cds.data["name"], y_range=(0,1400), 
           height=350, title="Stock inventory per location")

p.vbar(x='name', top='units', width=0.9, legend_field="name",
       line_color='white', 
       fill_color=factor_cmap('name', palette=Bright6, factors=cds.data["name"]),
       source=cds)
p.toolbar.logo=None
p.title.align = "center"
p.xgrid.grid_line_color = None
p.legend.orientation = "horizontal"
p.legend.location = "top_center"
show(p)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[37], line 17
#      15 p.legend.orientation = "horizontal"
#      16 p.legend.location = "top_center"
# ---> 17 show(p)
#
# File ~/.local/share/virtualenvs/quanta-Yd3H_Mzp/lib/python3.8/site-packages/bokeh/io/showing.py:143, in show(obj, browser, new, notebook_handle, notebook_url, **kwargs)
#     140 state = curstate()
#     142 if isinstance(obj, UIElement):
# --> 143     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     145 def is_application(obj: Any) -> TypeGuard[Application]:
#     146     return getattr(obj, '_is_a_bokeh_application_class', False)
#
# File ~/.local/share/virtualenvs/quanta-Yd3H_Mzp/lib/python3.8/site-packages/bokeh/io/showing.py:190, in _show_with_state(obj, state, browser, new, notebook_handle)
#     188 if state.notebook:
#     189     assert state.notebook_type is not None
# --> 190     comms_handle = run_notebook_hook(state.notebook_type, 'doc', obj, state, notebook_handle)
#     191     shown = True
#     193 if state.file or not shown:
#
# File ~/.local/share/virtualenvs/quanta-Yd3H_Mzp/lib/python3.8/site-packages/bokeh/io/notebook.py:367, in run_notebook_hook(notebook_type, action, *args, **kwargs)
#     365 if _HOOKS[notebook_type][action] is None:
#     366     raise RuntimeError(f"notebook hook for {notebook_type!r} did not install {action!r} action")
# --> 367 return _HOOKS[notebook_type][action](*args, **kwargs)
#
# File ~/.local/share/virtualenvs/quanta-Yd3H_Mzp/lib/python3.8/site-packages/bokeh/io/notebook.py:579, in show_doc(obj, state, notebook_handle)
#     575 '''
#     576
#     577 '''
#     578 if obj not in state.document.roots:
# --> 579     state.document.add_root(obj)
#     581 from ..embed.notebook import notebook_content
#     582 comms_target = make_id() if notebook_handle else None
#
# File ~/.local/share/virtualenvs/quanta-Yd3H_Mzp/lib/python3.8/site-packages/bokeh/document/document.py:318, in Document.add_root(self, model, setter)
#     315     return
#     317 with self.models.freeze():
# --> 318     self._roots.append(model)
#     320 self.callbacks.trigger_on_change(RootAddedEvent(self, model, setter))
#
# File /usr/lib/python3.8/contextlib.py:120, in _GeneratorContextManager.__exit__(self, type, value, traceback)
#     118 if type is None:
#     119     try:
# --> 120         next(self.gen)
#     121     except StopIteration:
#     122         return False
#
# File ~/.local/share/virtualenvs/quanta-Yd3H_Mzp/lib/python3.8/site-packages/bokeh/document/models.py:130, in DocumentModelManager.freeze(self)
#     128 self._push_freeze()
#     129 yield
# --> 130 self._pop_freeze()
#
# File ~/.local/share/virtualenvs/quanta-Yd3H_Mzp/lib/python3.8/site-packages/bokeh/document/models.py:280, in DocumentModelManager._pop_freeze(self)
#     278 self._freeze_count -= 1
#     279 if self._freeze_count == 0:
# --> 280     self.recompute()
#
# File ~/.local/share/virtualenvs/quanta-Yd3H_Mzp/lib/python3.8/site-packages/bokeh/document/models.py:227, in DocumentModelManager.recompute(self)
#     224     md._detach_document()
#     226 for ma in to_attach:
# --> 227     ma._attach_document(document)
#     228     self._new_models.add(ma)
#     230 self._models = recomputed
#
# File ~/.local/share/virtualenvs/quanta-Yd3H_Mzp/lib/python3.8/site-packages/bokeh/model/model.py:575, in Model._attach_document(self, doc)
#     572     return
#     574 if self.document is not None:
# --> 575     raise RuntimeError(f"Models must be owned by only a single document, {self!r} is already in a doc")
#     577 doc.theme.apply_to_model(self)
#     578 self.document = doc
#
# RuntimeError: Models must be owned by only a single document, FactorRange(id='p1209', ...) is already in a doc
